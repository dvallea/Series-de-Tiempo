# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
datos= pd.read_csv("opsd_germany_daily.csv")

# %%
datos.head()
# Out:
#          Date  Consumption  Wind  Solar  Wind+Solar
# 0  2006-01-01     1069.184   NaN    NaN         NaN
# 1  2006-01-02     1380.521   NaN    NaN         NaN
# 2  2006-01-03     1442.533   NaN    NaN         NaN
# 3  2006-01-04     1457.217   NaN    NaN         NaN
# 4  2006-01-05     1477.131   NaN    NaN         NaN

# %%
datos.describe()
# Out:
#        Consumption         Wind        Solar   Wind+Solar
# count  4383.000000  2920.000000  2188.000000  2187.000000
# mean   1338.675836   164.814173    89.258695   272.663481
# std     165.775710   143.692732    58.550099   146.319884
# min     842.395000     5.757000     1.968000    21.478000
# 25%    1217.859000    62.353250    35.179250   172.185500
# 50%    1367.123000   119.098000    86.407000   240.991000
# 75%    1457.761000   217.900250   135.071500   338.988000
# max    1709.568000   826.278000   241.580000   851.556000

# %%
datos['Date'] = pd.to_datetime(datos['Date'])

# %%
datos = datos.set_index('Date')

# %%
datos.head()
# Out:
#             Consumption  Wind  Solar  Wind+Solar
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN
# 2006-01-02     1380.521   NaN    NaN         NaN
# 2006-01-03     1442.533   NaN    NaN         NaN
# 2006-01-04     1457.217   NaN    NaN         NaN
# 2006-01-05     1477.131   NaN    NaN         NaN

# %% [markdown]
# ### opsd_daily = pd.read_csv('opsd_germany_daily.csv', index_col=0, parse_dates=True) **lo hace mas rapido**

# %%
datos["year"]=datos.index.year
datos["month"]=datos.index.month
datos['day'] = datos.index.day_name()

# %%
datos.head()
# Out:
#             Consumption  Wind  Solar  Wind+Solar  year  month        day
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN  2006      1     Sunday
# 2006-01-02     1380.521   NaN    NaN         NaN  2006      1     Monday
# 2006-01-03     1442.533   NaN    NaN         NaN  2006      1    Tuesday
# 2006-01-04     1457.217   NaN    NaN         NaN  2006      1  Wednesday
# 2006-01-05     1477.131   NaN    NaN         NaN  2006      1   Thursday

# %%
datos.loc["2006-04-27":"2006-04-30"]
# Out:
#             Consumption  Wind  Solar  Wind+Solar  year  month       day
# Date
# 2006-04-27     1384.681   NaN    NaN         NaN  2006      4  Thursday
# 2006-04-28     1362.570   NaN    NaN         NaN  2006      4    Friday
# 2006-04-29     1167.240   NaN    NaN         NaN  2006      4  Saturday
# 2006-04-30     1026.352   NaN    NaN         NaN  2006      4    Sunday

# %%
plt.figure(figsize=(20, 8))
datos["Consumption"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
cols_plot=["Consumption", "Solar", "Wind"]
axes = datos[cols_plot].plot(marker='.', alpha=0.5, linestyle='None', figsize=(11, 9), subplots=True)
for ax in axes: 
    ax.set_ylabel('Daily Totals (GWh)')

# %%
ax = datos.loc['2017', 'Consumption'].plot()
ax.set_ylabel('Daily Consumption (GWh)')
# Out:
# Text(0, 0.5, 'Daily Consumption (GWh)')
